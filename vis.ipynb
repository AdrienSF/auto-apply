# %% [markdown]
# ## See what form answers look like, view job descriptions

# %%
import json
import jsonlines as jsonl

# %%
with open('file_templates/form_answers.json') as f:
    form_answers = json.load(f)

# %%
form_answers = {k: None for k in form_answers}

# %%
for k, v in form_answers.items():
    print(k)
    print(v)
# Out:
# refered from
# None
# country
# None
# full name
# None
# forename / first name
# None
# surname / last name
# None
# email
# None
# phone device type
# None
# telephone number
# None
# address line 1
# None
# address city
# None
# address state
# None
# address postal code
# None
# how did you learn about us / hear about this opportunity?
# None
# are you legally authorized to work in the united states?
# None
# will you require sponsorship for work authorization in the united states?
# None
# gender
# None
# race
# None
# veteran status
# None
# additional information / cover letter
# None
# first link: linkedin
# None
# second link: github
# None
# skills
# None
# first work experience job title / position
# None
# first work experience company
# None
# first work experience start date (from)
# None
# first work from month
# None
# first work from year
# None
# first work experience end date (to)
# None
# first work to month
# None
# first work to year
# None
# first work experience description
# None
# second work experience job title / position
# None
# second work experience company
# None
# second work experience start date
# None
# second date from month
# None
# second date from year
# None
# second work experience end date
# None
# second work to month
# None
# second work to year
# None
# second work experience description
# None
# third work experience job title / position
# None
# third work experience company
# None
# third work experience start date
# None
# third work from month
# None
# third work from year
# None
# third work experience end date
# None
# third work to month
# None
# third work to year
# None
# third work experience description
# None
# fourth work experience job title / position
# None
# fourth work experience company
# None
# fourth work experience start date
# None
# fourth work from month
# None
# fourth work from year
# None
# fourth work experience end date
# None
# fourth work to month
# None
# fourth work to year
# None
# fourth work experience description
# None
# fifth work experience job title / position
# None
# fifth work experience company
# None
# fifth work experience start date
# None
# fifth work from month
# None
# fifth work from year
# None
# fifth work experience end date
# None
# fifth work to month
# None
# fifth work to year
# None
# fifth work experience description
# None
# sixth work experience job title / position
# None
# sixth work experience company
# None
# sixth work experience start date
# None
# sixth work from month
# None
# sixth work from year
# None
# sixth work experience end date
# None
# sixth work to month
# None
# sixth work to year
# None
# sixth work experience description
# None
# first education university
# None
# first education degree
# None
# first education field of study/concentration/major
# None
# first education from
# None
# first education to
# None
# first education GPA
# None
# second education university
# None
# second education degree
# None
# second education field of study
# None
# second education first field of study/concentration/major
# None
# second education second field of study/concentration/major
# None
# second education from
# None
# second education to
# None
# second education GPA
# None

# %%
with open('file_templates/form_answers.json', 'w') as f:
    json.dump(form_answers, f, indent=2)

# %%
with jsonl.open('file_templates/applied_jobs.jsonl') as f:
    for e in f:
        print(e['description'])
